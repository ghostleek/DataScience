# %%
import pandas as pd
# Read train data
tesla_df = pd.read_csv('comments.csv')
tesla_df.head(100)
# Out:
#        Video ID                                              Title  \
# 0   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 1   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 2   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 3   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 4   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 5   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 6   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 7   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 8   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 9   SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 10  SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 11  SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# 12  SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# ...

# %%
tesla_df.describe()
# Out:
#            Video ID                                              Title  \
# count          5677                                               5677
# unique           13                                                 13
# top     SwvDOdBHYBw  WATCH LIVE! Elon Musk presents the new Tesla C...
# freq           4974                                               4974
#
#                 Comment
# count              5677
# unique             5619
# top     Is this a joke?
# freq                  5

# %%
#Import the libraries
from textblob import TextBlob
import nltk
from newspaper import Article
import re

# %%
obj = tesla_df['Comment'][0]
obj
# Out:
# "It's funny how they want to promote Tesla's name but then again discredit his genuine true inventions in the past bunch of criminals and scumbags"

# %%
#returns the sentiment of text
#by returning a value between -1.0 and 1.0
def get_text_sentiment(text): 
# create TextBlob object of passed tweet text 
    analysis = TextBlob(obj) 
# set sentiment 
    if analysis.sentiment.polarity > 0: 
        return 'positive'
    elif analysis.sentiment.polarity == 0: 
        return 'neutral'
    else: 
        return 'negative'
get_text_sentiment(obj)
# Out:
# 'positive'

# %%
def clean_comment(text): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", text).split())

# %%
clean_comment(obj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-49d1c3bc8194> in <module>
# ----> 1 clean_comment(obj)
#
# NameError: name 'clean_comment' is not defined

# %%
tesla_df['Comment']
# Out:
# 0       It's funny how they want to promote Tesla's na...
# 1       The more I look at it, the more it's growing o...
# 2       Wow!!! A indestructible window that got destro...
# 3                               Another rich people’s toy
# 4        Finally, people from the 60s are no longer wrong
# 5       Not even his bullions of dollars can save him ...
# 6                   Am SUPPOSED to be impressed or what!?
# 7       Notice he said "shatter proof" not bullet proo...
# 8       Sorry I think it is so ugly. I guess I'm old s...
# 9       The more I look at the cooler it gets. Yes at ...
# 10                                  Window broken at 7:57
# 11      Am I the only one?? Or does he not know anythi...
# 12      That tug of war lmao. A base model f150 2x2, t...
# 13            Tows 14,000 pounds with a range of 32 feet.
# 14      That was on purpose, the glass obviously can w...
# 15       That's the ugliest fucking thing I've ever seen.
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt


plt.figure(figsize=(15,8))
Tweets_Word_Cloud = WordCloud(width=800, 
                              height=400,
                              background_color="black", 
                              max_words=100,
                              relative_scaling = 1.0).generate(tesla_df['Comment']) # input string here
plt.imshow(Tweets_Word_Cloud)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-6fbef6d7b7b6> in <module>
#       7                               background_color="black",
#       8                               max_words=100,
# ----> 9                               relative_scaling = 1.0).generate(tesla_df['Comment']) # input string here
#      10 plt.imshow(Tweets_Word_Cloud)
#      11 plt.axis("off")
#
# ~/anaconda3/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     617         self
#     618         """
# --> 619         return self.generate_from_text(text)
#     620
#     621     def _check_generated(self):
#
# ~/anaconda3/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     598         self
#     599         """
# --> 600         words = self.process_text(text)
#     601         self.generate_from_frequencies(words)
# ...

# %%
def get_tweets(tweets): 
    # empty list to store parsed tweets 
    tweets = [] 
  
    try: 
        tweets = tesla_df['Comment']
        # parsing tweets one by one 
        for tweet in tweets: 
            # empty dictionary to store required params of a tweet 
            parsed_tweet = {} 
  
            # saving text of tweet 
            parsed_tweet['text'] = tweet.text 
            # saving sentiment of tweet 
            parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
  
        # appending parsed tweet to tweets list 
        if tweet.retweet_count > 0: 
            # if tweet has retweets, ensure that it is appended only once 
            if parsed_tweet not in tweets: 
                tweets.append(parsed_tweet) 
            else: 
                tweets.append(parsed_tweet)  
        # return parsed tweets 
        return tweets
# Out:
#   File "<ipython-input-54-82eabe4a068a>", line 25
#     return tweets
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
get_tweets(tweets)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-51e3575ef06a> in get_tweets(tweets)
#      15             # saving text of tweet
# ---> 16             parsed_tweet['text'] = tweet.text
#      17             # saving sentiment of tweet
#
# AttributeError: 'str' object has no attribute 'text'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-6608a9e5e0a7> in <module>
# ----> 1 get_tweets(tweets)
#
# <ipython-input-41-51e3575ef06a> in get_tweets(tweets)
#      29         return tweets
#      30
# ---> 31     except tweepy.TweepError as e:
#      32         # print error (if any)
#      33         print("Error : " + str(e))
#
# NameError: name 'tweepy' is not defined

# %%
def main(): 
    # calling function to get tweets 
    tweets = tesla_df['Comment']
  
    # picking positive tweets from tweets 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    # percentage of positive tweets 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    # picking negative tweets from tweets 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    # percentage of negative tweets 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
  
    # printing first 5 positive tweets 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text']) 
  
    # printing first 5 negative tweets 
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 
  
main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-11dc3b92ed03> in <module>
#      22         print(tweet['text'])
#      23
# ---> 24 main()
#
# <ipython-input-35-11dc3b92ed03> in main()
#       4
#       5     # picking positive tweets from tweets
# ----> 6     ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
#       7     # percentage of positive tweets
#       8     print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
#
# <ipython-input-35-11dc3b92ed03> in <listcomp>(.0)
#       4
#       5     # picking positive tweets from tweets
# ----> 6     ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
#       7     # percentage of positive tweets
#       8     print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
#
# TypeError: string indices must be integers
